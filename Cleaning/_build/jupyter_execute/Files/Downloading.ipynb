# %% [markdown]
# # Navigating Pavlovia to find the data
# ```{note}
# Login to Pavlovia using the following Login details:
#
# **Pavlovia login:** smtashji@caltech.edu
# **Password:**Danlpup2003!*
# ```
#
# Go to experiments
# Neuropaths-questionnaires
# Scroll down, wait for it to load then scroll down again
# Ensure CSV is chosen then click download results
#
# This will download a Zip file of all participants questionnaires
#
# Anything under 9KB total size is incomplete and can be disreagarded
#
# ```
# If you have a mac, you can 'ctl + f' to search for names or particpiant IDs within the CSV files. Unfortunately windows users are unable to do this and will have to open each file manually. If you downloaded all the files, you will no longer be able to search based on date completed because all files' dates will be teh day they were downloaded.
# ```
