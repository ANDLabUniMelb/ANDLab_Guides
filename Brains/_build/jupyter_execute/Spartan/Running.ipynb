# %% [markdown]
# # 2b.  How to run the script
#
# Open up VS code and login Unimelb spartan. If you don't have this yet following these steps to download it:
# >[Tutorial](https://andlabunimelb.github.io/ANDLab_Guides/Coding/gettingstarted/prereq.html)
