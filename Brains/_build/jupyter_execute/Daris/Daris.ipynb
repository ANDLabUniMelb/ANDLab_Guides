# %% [markdown]
# # 1a. Daris
# ```
# Daris is the where the radiographers will upload all images collected from each scan. You can login to DARIS using your Unimelb credentials. Your acess will have to be approved prior to logon.
# ```
# Navigate to the Neuropaths folder.Then select the correct participant based upon their DARIS ID, these can be found on the running particiapnt tracker.
#
#
# The file we are looking for is listed as MP2RAGE (we will be using the file without distortion correction)
#
# <img src="../_images/MP2Rage.jpng" style="width: 50%;">
#
#
#
# > If we have had to run multiple structural scans because the participant moved all structural scans should be uploaded to DARIS. Scroll down as repeat structurals often occur towards the end. If there are multiple structruals the final one is often the clearest, but don't always assume this. Open the files and compare to find the clearest.
